# %% [markdown]
# # HFT Platform - Getting Started
#
# This notebook demonstrates how to use the research data loader to access historical market data.

# %%
# Add src to path
import sys

sys.path.insert(0, '../src')

from hft_platform.research import DataLoader

# %%
# Initialize data loader
loader = DataLoader()

# List available symbols
symbols = loader.list_symbols()
print(f"Available symbols: {symbols}")

# %%
# Load market data (example)
# df = loader.load_market_data(symbol="2330", start="2024-01-01", end="2024-01-31")
# df.head()

# %%
# Load sample data for testing
sample_df = loader.load_sample("sample_feed")
sample_df.head() if not sample_df.empty else print("No sample data found")
